# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/bunarisaisumanth/Downloads/IMDb_Dataset.csv")

# %%
print(data)
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
data.head(20)
# Out:
#                                                 Title  IMDb Rating  Year  \
# 0                                           Gladiator          8.5  2000
# 1       Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2                Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                                Inglourious Basterds          8.4  2009
# 4                                         Borderlands          7.1  2024
# 5                                       Jurassic Park          8.2  1993
# 6                                   The Fifth Element          7.6  1997
# 7                                          Inside Out          8.1  2015
# 8                        Descendants: The Rise of Red          7.1  2024
# 9                                                Wish          5.6  2023
# 10                                   The Hunger Games          7.2  2012
# 11             Rebel Moon - Part One: A Child of Fire          5.6  2023
# ...

# %%
data.tail(20)
# Out:
#                            Title  IMDb Rating  Year Certificates      Genre  \
# 380                 Inside Out 2          7.1  2024           PG  Animation
# 381        Bad Boys: Ride or Die          7.1  2024            R     Action
# 382                  Beetlejuice          7.5  1988           PG     Comedy
# 383                      Hit Man          7.4  2023            R     Action
# 384              Laapataa Ladies          8.5  2023            R     Comedy
# 385  Ghostbusters: Frozen Empire          6.2  2024        PG-13  Adventure
# 386               A Simple Favor          6.8  2018            R     Comedy
# 387                  Poor Things          7.9  2023            R     Comedy
# 388           Thelma the Unicorn          5.8  2024           PG  Animation
# 389                    Unfrosted          5.5  2024        PG-13  Biography
# 390                 Emilia Perez          7.2  2024            R     Comedy
# ...

# %%
data['Title'].head(10)
# Out:
# 0                                        Gladiator
# 1    Mission: Impossible - Dead Reckoning Part One
# 2             Rebel Moon - Part Two: The Scargiver
# 3                             Inglourious Basterds
# 4                                      Borderlands
# 5                                    Jurassic Park
# 6                                The Fifth Element
# 7                                       Inside Out
# 8                     Descendants: The Rise of Red
# 9                                             Wish
# Name: Title, dtype: object

# %%
data[['Title', 'IMDb Rating']].head(10)
# Out:
#                                            Title  IMDb Rating
# 0                                      Gladiator          8.5
# 1  Mission: Impossible - Dead Reckoning Part One          7.7
# 2           Rebel Moon - Part Two: The Scargiver          5.2
# 3                           Inglourious Basterds          8.4
# 4                                    Borderlands          7.1
# 5                                  Jurassic Park          8.2
# 6                              The Fifth Element          7.6
# 7                                     Inside Out          8.1
# 8                   Descendants: The Rise of Red          7.1
# 9                                           Wish          5.6

# %%
print(data.shape)
print(data.shape[0])
print(data.shape[1])
# Out:
# (400, 9)
# 400
# 9

# %%
list(data.columns)
# Out:
# ['Title',
#  'IMDb Rating',
#  'Year',
#  'Certificates',
#  'Genre',
#  'Director',
#  'Star Cast',
#  'MetaScore',
#  'Duration (minutes)']

# %%
data.isnull()
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0    False        False  False         False  False     False      False
# 1    False        False  False         False  False     False      False
# 2    False        False  False         False  False     False      False
# 3    False        False  False         False  False     False      False
# 4    False        False  False         False  False     False      False
# ..     ...          ...    ...           ...    ...       ...        ...
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 0        False               False
# ...

# %%
data.isnull().head(10)
# Out:
#    Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0  False        False  False         False  False     False      False
# 1  False        False  False         False  False     False      False
# 2  False        False  False         False  False     False      False
# 3  False        False  False         False  False     False      False
# 4  False        False  False         False  False     False      False
# 5  False        False  False         False  False     False      False
# 6  False        False  False         False  False     False      False
# 7  False        False  False         False  False     False      False
# 8  False        False  False         False  False     False      False
# 9  False        False  False         False  False     False      False
#
#    MetaScore  Duration (minutes)
# 0      False               False
# 1      False               False
# 2      False               False
# 3      False               False
# ...

# %%
data.isna().tail(5)
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 395      False               False
# 396      False               False
# 397      False               False
# 398      False               False
# 399      False               False

# %%
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data.isna().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Duration (minutes)    False
# dtype: bool

# %%
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Runtime (minutes)
# count   400.000000   400.000000  400.000000         400.000000
# mean      7.110250  2015.150000   66.898750         116.334750
# std       0.932251    13.470194   15.312006          21.369757
# min       3.900000  1939.000000   26.000000          80.000000
# 25%       6.700000  2010.750000   57.750000         101.000000
# 50%       7.100000  2023.000000   66.900000         116.000000
# 75%       7.700000  2024.000000   77.000000         124.000000
# max       9.200000  2025.000000  100.000000         206.000000

# %%
data[data.index==20]
# Out:
#               Title  IMDb Rating  Year Certificates      Genre       Director  \
# 20  Kung Fu Panda 4          6.3  2024           PG  Animation  Mike Mitchell
#
#                                  Star Cast  MetaScore  Duration (minutes)
# 20  Jonathan AibelGlenn BergerDarren Lemke       54.0                94.0

# %%
data[data.index.isin(range(20,50))]
# Out:
#                                                 Title  IMDb Rating  Year  \
# 20                                    Kung Fu Panda 4          6.3  2024
# 21                         Mad Max Beyond Thunderdome          6.2  1985
# 22                                     Manjummel Boys          8.4  2024
# 23                                       Golden Kamuy          6.4  2024
# 24                                       Interstellar          8.7  2014
# 25                                 Planet of the Apes          8.0  1968
# 26                                             Barbie          6.8  2023
# 27                                           Twisters          7.1  2024
# 28  The Hunger Games: The Ballad of Songbirds & Sn...          6.7  2023
# 29                                       Inside Out 2          7.1  2024
# 30                              Bad Boys: Ride or Die          7.1  2024
# 31                        Mad Max 2: The Road Warrior          7.6  1981
# ...

# %%
data.loc[278]
# Out:
# Title                                                 Cars
# IMDb Rating                                            7.2
# Year                                                  2006
# Certificates                                             G
# Genre                                            Animation
# Director                                     John Lasseter
# Star Cast             John LasseterJoe RanftJorgen Klubien
# MetaScore                                             73.0
# Duration (minutes)                                   116.0
# Name: 278, dtype: object

# %%
data.iloc[90]
# Out:
# Title                                   Despicable Me 4
# IMDb Rating                                         7.1
# Year                                               2024
# Certificates                                         PG
# Genre                                         Animation
# Director                                   Chris Renaud
# Star Cast             Steve CarellKristen WiigJoey King
# MetaScore                                          66.9
# Duration (minutes)                                 95.0
# Name: 90, dtype: object

# %%
data.loc[45:58]
# Out:
#                                   Title  IMDb Rating  Year Certificates  \
# 45                   Mad Max: Fury Road          8.1  2015            R
# 46                                Atlas          5.6  2024        PG-13
# 47                       Dune: Part Two          8.6  2024        PG-13
# 48    Kingdom of the Planet of the Apes          7.2  2024        PG-13
# 49              Furiosa: A Mad Max Saga          7.9  2024            R
# 50                               WALL·E          8.4  2008            G
# 51  Spider-Man: Beyond the Spider-Verse          7.1  2015            R
# 52                             Hercules          7.3  1997            G
# 53                                 Sing          7.1  2016           PG
# 54                    Castle in the Sky          8.0  1986           PG
# 55                       Monsters, Inc.          8.1  2001            G
# 56                              Tangled          7.7  2010           PG
# ...

# %%
data.loc[59:69]
# Out:
#                                           Title  IMDb Rating  Year  \
# 59                 Puss in Boots: The Last Wish          7.8  2022
# 60                                      Encanto          7.2  2021
# 61                                         Coco          8.4  2017
# 62                                       Frozen          7.4  2013
# 63                        Mufasa: The Lion King          7.1  2024
# 64                         Howl's Moving Castle          8.2  2004
# 65                                     Zootopia          8.0  2016
# 66  Teenage Mutant Ninja Turtles: Mutant Mayhem          7.2  2023
# 67                                Kung Fu Panda          7.6  2008
# 68                                The Lion King          6.8  2019
# 69            Spider-Man: Into the Spider-Verse          8.4  2018
#
#    Certificates      Genre         Director  \
# 59           PG  Animation    Joel Crawford
# 60           PG  Animation       Jared Bush
# ...

# %%
data.rename(columns = {'Title':'Movie Name', 'Duration (minutes)':'Runtime (minutes)'}, inplace = True)
data.head(10)
# Out:
#                                       Movie Name  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
# 5                                  Jurassic Park          8.2  1993
# 6                              The Fifth Element          7.6  1997
# 7                                     Inside Out          8.1  2015
# 8                   Descendants: The Rise of Red          7.1  2024
# 9                                           Wish          5.6  2023
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# ...

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action       138
# Animation     95
# Comedy        38
# Adventure     35
# Crime         31
# Horror        29
# Drama         24
# Fantasy        5
# Biography      4
# Thriller       1
# Name: count, dtype: int64

# %%
data['Certificates'].value_counts()
# Out:
# Certificates
# R            183
# PG-13         96
# PG            93
# G             16
# Not Rated      4
# TV-G           2
# 16+            2
# Approved       1
# TV-MA          1
# NC-17          1
# TV-PG          1
# Name: count, dtype: int64

# %%
data['IMDb Rating'].head(10) > 7.0
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: IMDb Rating, dtype: bool

# %%
dt = data[data.index.isin(range(20,70))]
d = dt.loc[dt['IMDb Rating'] <= 8.5]
sns.barplot(y = "Genre", x = "IMDb Rating", data = data)
# Out:
# <Axes: xlabel='IMDb Rating', ylabel='Genre'>

# %%
dt = data[data.index.isin(range(20,70))]
d1 = dt.loc[data['Year'] < 2020]
sns.lineplot(data = d1, x = "Genre", y = "Year")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Genre', ylabel='Year'>

# %%
dt = data[data.index.isin(range(20,200))]
d2 = dt.loc[data['Duration (minutes)'] <= 155.0]
sns.lineplot(data = d2, y = "Genre", x = "Duration (minutes)")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Duration (minutes)', ylabel='Genre'>

# %%
dt = data[data.index.isin(range(120,300))]
sns.countplot(y='Genre', data = dt)
# Out:
# <Axes: xlabel='count', ylabel='Genre'>

# %%
dt = data[data.index.isin(range(70,225))]
dt1 = dt[dt['IMDb Rating'] >= 5.5]
sns.boxplot(x='Year', data = dt1)
plt.show()

# %%
dt = data[data.index.isin(range(100,120))]
sns.boxplot(y = "Year", x = "IMDb Rating", data = dt)
# Out:
# <Axes: xlabel='IMDb Rating', ylabel='Year'>

# %%
dt= data.head(34)
dt1 = dt[dt['IMDb Rating'] >= 6.0]
sns.violinplot(x='IMDb Rating', y='Year', data = dt1)
plt.show()

# %%
dt= data.head(134)
dt1 = dt[dt['IMDb Rating'] <= 8.0]
sns.stripplot(x='IMDb Rating' , y='Year', data = dt1)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dt=data.head(210)
sns.pairplot(dt[['IMDb Rating','MetaScore']])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dt = data.tail(50)
sns.displot(dt["Certificates"])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dt = data[data.index.isin(range(20,45))]
sns.histplot(data = dt, y = "Director", kde = True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Count', ylabel='Director'>

# %%
data.hist(figsize = (10, 10))
# Out:
# array([[<Axes: title={'center': 'IMDb Rating'}>,
#         <Axes: title={'center': 'Year'}>],
#        [<Axes: title={'center': 'MetaScore'}>,
#         <Axes: title={'center': 'Duration (minutes)'}>]], dtype=object)

# %%
sns.pairplot(data, hue = 'Genre')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
dt = data[data.index.isin(range(12,35))]
dt.loc[data['IMDb Rating'] >= 7.0]
sns.catplot(x = 'Year', y = 'Director', hue = 'Genre', data = dt)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
labels = data['Year'].head(15)
size = data['IMDb Rating'].head(15)
plt.pie(size, labels = labels, autopct = "%1.1f%%", startangle = 90)
plt.title("Pie chart For IMDb Rating and year")
plt.show()

# %%
dt = data[data.index.isin(range(0,7))]
dt_sort = dt.sort_values(by = "Year")
print(dt_sort)
# Out:
#                                            Title  IMDb Rating  Year  \
# 5                                  Jurassic Park          8.2  1993
# 6                              The Fifth Element          7.6  1997
# 0                                      Gladiator          8.5  2000
# 3                           Inglourious Basterds          8.4  2009
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 5        PG-13     Action       Steven Spielberg
# 6        PG-13     Action             Luc Besson
# 0            R     Action           Ridley Scott
# 3            R  Adventure      Quentin Tarantino
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 4            R     Action               Eli Roth
#
# ...

# %%
dt = data.head(33)
dt.sort_index(ascending = True).tail(10)
# Out:
#                                                 Title  IMDb Rating  Year  \
# 23                                       Golden Kamuy          6.4  2024
# 24                                       Interstellar          8.7  2014
# 25                                 Planet of the Apes          8.0  1968
# 26                                             Barbie          6.8  2023
# 27                                           Twisters          7.1  2024
# 28  The Hunger Games: The Ballad of Songbirds & Sn...          6.7  2023
# 29                                       Inside Out 2          7.1  2024
# 30                              Bad Boys: Ride or Die          7.1  2024
# 31                        Mad Max 2: The Road Warrior          7.6  1981
# 32                                 Godzilla Minus One          7.9  2023
#
#    Certificates      Genre               Director  \
# 23            R     Action          Shigeaki Kubo
# 24        PG-13  Adventure      Christopher Nolan
# ...

# %%
dt = data.head(83)
dt.sort_index(ascending = False).head(10)
# Out:
#                            Title  IMDb Rating  Year Certificates      Genre  \
# 82         The Boy and the Heron          7.6  2023        PG-13  Animation
# 81              Transformers One          7.1  2024            R  Animation
# 80          Trolls Band Together          6.0  2023           PG  Animation
# 79                        Sing 2          7.3  2021           PG  Animation
# 78                  Finding Nemo          8.2  2003            G  Animation
# 77  Harold and the Purple Crayon          7.1  2024           PG  Animation
# 76                         Moana          7.6  2016           PG  Animation
# 75                   Ratatouille          8.1  2007            G  Animation
# 74                     Elemental          7.0  2023           PG  Animation
# 73                    Your Name.          8.4  2016            R  Animation
#
#            Director                                          Star Cast  \
# ...

# %%
dt= data.head(134)
dt1 = dt[dt['IMDb Rating'] <= 8.0]
#plt.scatter(x='IMDb Rating' , y='Year', data = dt1)
plt.show()
plt.scatter(dt['IMDb Rating'], dt['Year'], alpha = 0.7)
